# %%
import cv2
import numpy as np
import matplotlib

print("OpenCV version:", cv2.__version__)
print("NumPy version:", np.__version__)
print("Matplotlib version:", matplotlib.__version__)
# Out:
# OpenCV version: 4.10.0
# NumPy version: 1.26.4
# Matplotlib version: 3.9.0

# %%
# import cv2
# import numpy as np

# def detect_and_save_kicker_upper(image_path, save_path):
#     # Load the image
#     image = cv2.imread(image_path)
#     if image is None:
#         print("Error: Image not found.")
#         return None

#     # Step 1: Image Preprocessing
#     gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

#     # Step 2: Edge Detection
#     edges = cv2.Canny(blurred_image, 50, 150)

#     # Step 3: Define ROI (upper half of the image)
#     height, width = edges.shape
#     roi = edges[0:int(height / 2), 0:width]

#     # Step 4: Save the resulting ROI image
#     cv2.imwrite(save_path, roi)

#     return roi

# # Example usage:
# # roi_image = detect_and_save_kicker_upper("path/to/your/image.jpg", "path/to/save/roi_image.jpg")


# # Example usage
# upper_roi = detect_and_save_kicker_upper('False_images_class1/cam2024_09_26_17_23_59.jpg', 'Reference_Imgs/invalid noisy roi.jpg')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Function to detect kicker using white pixel coverage
def detect_kicker_by_white_pixels(image_path, threshold_percentage=5, threshold_value=127):
    # Load the input image in grayscale
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print("Error: Image not found.")
        return False

    # Apply binary threshold to convert the image to black and white
    _, img_bw = cv2.threshold(img, threshold_value, 255, cv2.THRESH_BINARY)

    # Focus only on the upper half of the image (ROI where kicker might be)
    height, width = img.shape
    upper_region = img_bw[0:int(height / 2), :]  # Upper half of the image

    # Calculate the total number of pixels in the upper region
    total_pixels = upper_region.size

    # Count the number of white pixels (255) in the upper region
    white_pixels = np.sum(upper_region == 255)

    # Calculate the percentage of white pixels
    white_pixel_percentage = (white_pixels / total_pixels) * 100

    # Visualize the upper region and the binary image
    # plt.subplot(121), plt.imshow(img_bw, cmap='gray')
    # plt.title('Binary Image (BW)'), plt.xticks([]), plt.yticks([])
    # plt.subplot(122), plt.imshow(upper_region, cmap='gray')
    # plt.title('Upper Region'), plt.xticks([]), plt.yticks([])
    # plt.show()

    # Print the percentage of white pixels
    print(f'White Pixel Percentage in Upper Region: {white_pixel_percentage:.2f}%')

    # Check if the percentage exceeds the threshold for detecting the kicker
    if white_pixel_percentage > threshold_percentage:
        print("Kicker Detected by White Pixels")
        return True
    else:
        print("No Kicker Detected by White Pixels")
        return False


# Step 1: Kicker Detection
def detect_kicker(image_path, min_line_count=2, min_intersect_count=1, white_pixel_threshold_percentage=5):
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        print("Error: Image not found.")
        return None, None

    # Step 1: Image Preprocessing
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

    # Step 2: Edge Detection
    edges = cv2.Canny(blurred_image, 50, 150)

    # Step 3: Define ROI (upper half of the image)
    height, width = edges.shape
    roi = edges[0:int(height/2), 0:width]

    # Step 4: Pattern Recognition (Hough Transform for lines)
    lines = cv2.HoughLines(roi, 1, np.pi/180, 100)

    # Step 5: Analyze Detected Lines
    kicker_detected = False
    line_image = np.zeros_like(image)
    line_count = 0
    intersect_count = 0
    line_data = []

    if lines is not None:
        for rho, theta in lines[:, 0]:
            a = np.cos(theta)
            b = np.sin(theta)
            x0 = a * rho
            y0 = b * rho
            x1 = int(x0 + 1000 * (-b))
            y1 = int(y0 + 1000 * (a))
            x2 = int(x0 - 1000 * (-b))
            y2 = int(y0 - 1000 * (a))
            cv2.line(line_image, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Store line data for intersection check
            line_data.append(((x1, y1), (x2, y2)))
            line_count += 1

    # Step 6: Check if sufficient lines are detected
    if line_count >= min_line_count:
        # Step 7: Check for line intersections to detect kicker-like patterns
        for i in range(len(line_data)):
            for j in range(i + 1, len(line_data)):
                if check_line_intersection(line_data[i], line_data[j]):
                    intersect_count += 1

    # If enough intersections are found, we assume a kicker is detected
    kicker_detected = (line_count >= min_line_count) and (intersect_count >= min_intersect_count)

    # # Visualization
    # plt.figure(figsize=(12, 10))

    # # Edges
    # plt.subplot(2, 3, 4)
    # plt.imshow(edges, cmap='gray')
    # plt.title("Detected Edges")
    # plt.axis("off")

    # # ROI
    # #cv2.imwrite("ROI.jpg",roi)
    # plt.subplot(2, 3, 5)
    # plt.imshow(roi, cmap='gray')
    # plt.title("ROI (Upper Half)")
    # plt.axis("off")

    # # Detected Lines (if any)
    # plt.subplot(2, 3, 6)
    # plt.imshow(cv2.cvtColor(line_image, cv2.COLOR_BGR2RGB))
    # if kicker_detected:
    #     plt.title(f"(Lines: {line_count}, Intersections: {intersect_count})")
    # else:
    #     plt.title("No Kicker Detected")
    # plt.axis("off")

    # plt.tight_layout()
    # plt.show()

    # Check both line detection and white pixel coverage
    if kicker_detected:
        print("Test 1 successful. Checking white pixel coverage...")
        if not detect_kicker_by_white_pixels(image_path, threshold_percentage=white_pixel_threshold_percentage):
            print("Test 2 failed. No kicker detected (due to insufficient white pixels).")
            return None, None
        else:
            print("Kicker detected (both tests passed).")
            return roi, edges  # Both tests passed
    else:
        print("Test 1 failed. Checking white pixel coverage...")
        if detect_kicker_by_white_pixels(image_path, threshold_percentage=white_pixel_threshold_percentage):
            print("Kicker detected (based on white pixel coverage).")
            return roi, edges  # Kicker detected based on white pixel coverage
        else:
            print("All tests failed. No kicker detected.")
            return None, None


# Function to check if two lines intersect
def check_line_intersection(line1, line2):
    def ccw(A, B, C):
        return (C[1] - A[1]) * (B[0] - A[0]) > (B[1] - A[1]) * (C[0] - A[0])

    (A, B) = line1
    (C, D) = line2
    return ccw(A, C, D) != ccw(B, C, D) and ccw(A, B, C) != ccw(A, B, D)

# %% [markdown]
# ### Multiple checks

# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt

# # Function to extract the central vertical region from an image
# def extract_vertical_central_region(image, width_ratio=0.3, height_ratio=0.8):
#     height, width = image.shape
#     central_height = int(height * height_ratio)
#     central_width = int(width * width_ratio)
    
#     start_y = (height - central_height) // 2
#     start_x = (width - central_width) // 2
    
#     return image[start_y:start_y + central_height, start_x:start_x + central_width]

# # Function for template matching
# def template_matching(current_central, valid_central, invalid_central):
#     valid_result = cv2.matchTemplate(current_central, valid_central, cv2.TM_CCOEFF_NORMED)
#     invalid_result = cv2.matchTemplate(current_central, invalid_central, cv2.TM_CCOEFF_NORMED)

#     valid_match = np.max(valid_result)
#     invalid_match = np.max(invalid_result)

#     return valid_match, invalid_match

# # Function for feature matching using ORB
# def feature_matching(current_central, valid_central, invalid_central):
#     orb = cv2.ORB_create()
#     keypoints1, descriptors1 = orb.detectAndCompute(current_central, None)
#     keypoints2, descriptors2 = orb.detectAndCompute(valid_central, None)
#     keypoints3, descriptors3 = orb.detectAndCompute(invalid_central, None)

#     # Use BFMatcher for matching
#     bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
#     matches_valid = bf.match(descriptors1, descriptors2)
#     matches_invalid = bf.match(descriptors1, descriptors3)

#     valid_similarity = len(matches_valid)
#     invalid_similarity = len(matches_invalid)

#     return valid_similarity, invalid_similarity

# # Function to check kicker orientation based on template and feature matching
# def check_kicker_orientation(current_roi, valid_roi_path, invalid_roi_path, width_ratio=0.3, height_ratio=0.8):
#     valid_roi = cv2.imread(valid_roi_path, cv2.IMREAD_GRAYSCALE)
#     invalid_roi = cv2.imread(invalid_roi_path, cv2.IMREAD_GRAYSCALE)
    
#     if valid_roi is None or invalid_roi is None:
#         print("Error: One or both reference ROIs not found.")
#         return False

#     # Extract central vertical regions
#     current_central = extract_vertical_central_region(current_roi, width_ratio, height_ratio)
#     valid_central = extract_vertical_central_region(valid_roi, width_ratio, height_ratio)
#     invalid_central = extract_vertical_central_region(invalid_roi, width_ratio, height_ratio)

#     # Test 1: Template Matching
#     valid_match, invalid_match = template_matching(current_central, valid_central, invalid_central)

#     # Test 2: Feature Matching
#     valid_similarity, invalid_similarity = feature_matching(current_central, valid_central, invalid_central)

#     # Visualize results
#     plt.figure(figsize=(18, 6))
    
#     plt.subplot(1, 3, 1)
#     plt.imshow(current_central, cmap='gray')
#     plt.title("Current ROI Vertical Region")
#     plt.axis("off")

#     plt.subplot(1, 3, 2)
#     plt.title(f"Template Match Valid: {valid_match:.4f}, Feature Matches: {valid_similarity}")
#     plt.axis("off")

#     plt.subplot(1, 3, 3)
#     plt.title(f"Template Match Invalid: {invalid_match:.4f}, Feature Matches: {invalid_similarity}")
#     plt.axis("off")

#     plt.tight_layout()
#     plt.show()

#     # Decision Logic
#     if valid_match > invalid_match and valid_similarity > invalid_similarity:
#         print("Kicker is in a valid orientation.")
#         return True
#     else:
#         print("Kicker is in an invalid orientation.")
#         return False

# # Full pipeline function
# def kicker_pipeline(image_path, valid_roi_path, invalid_roi_path, threshold=65, white_pixel_threshold_percentage=5):
#     # Step 1: Detect Kicker
#     current_roi, current_edges = detect_kicker(image_path, white_pixel_threshold_percentage=white_pixel_threshold_percentage)
#     if current_roi is None:
#         return False  # No kicker detected

#     # Step 2: Check Orientation if kicker detected
#     return check_kicker_orientation(current_roi, valid_roi_path, invalid_roi_path)

# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt

# # Function to extract the central vertical region from an image
# def extract_vertical_central_region(image, width_ratio=0.3, height_ratio=0.8):
#     height, width = image.shape
#     central_height = int(height * height_ratio)
#     central_width = int(width * width_ratio)
    
#     start_y = (height - central_height) // 2
#     start_x = (width - central_width) // 2
    
#     return image[start_y:start_y + central_height, start_x:start_x + central_width]

# # Function for template matching
# def template_matching(current_central, reference_central):
#     result = cv2.matchTemplate(current_central, reference_central, cv2.TM_CCOEFF_NORMED)
#     match_score = np.max(result)
#     return match_score

# # Function for feature matching using ORB
# def feature_matching(current_central, reference_central):
#     orb = cv2.ORB_create()
#     keypoints1, descriptors1 = orb.detectAndCompute(current_central, None)
#     keypoints2, descriptors2 = orb.detectAndCompute(reference_central, None)

#     # Use BFMatcher for matching
#     bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
#     matches = bf.match(descriptors1, descriptors2)
    
#     return len(matches)  # Number of matches

# # Function to check kicker orientation based on multiple reference images
# def check_kicker_orientation(current_roi, valid_roi_paths, width_ratio=0.3, height_ratio=0.8):
#     # Load all reference ROIs
#     valid_rois = [cv2.imread(path, cv2.IMREAD_GRAYSCALE) for path in valid_roi_paths]
    
#     # Check if any ROI is None
#     if any(roi is None for roi in valid_rois):
#         print("Error: One or more reference ROIs not found.")
#         return False

#     # Extract central vertical regions
#     current_central = extract_vertical_central_region(current_roi, width_ratio, height_ratio)
#     central_regions = [extract_vertical_central_region(roi, width_ratio, height_ratio) for roi in valid_rois]

#     # Initialize scores
#     scores = []

#     # Compare current central region with all reference central regions
#     for reference_central in central_regions:
#         template_score = template_matching(current_central, reference_central)
#         feature_score = feature_matching(current_central, reference_central)
#         scores.append((template_score, feature_score))

#     # Visualize results
#     plt.figure(figsize=(12, 6))
    
#     plt.subplot(1, 2, 1)
#     plt.imshow(current_central, cmap='gray')
#     plt.title("Current ROI Vertical Region")
#     plt.axis("off")

#     plt.subplot(1, 2, 2)
#     for i, (template_score, feature_score) in enumerate(scores):
#         plt.text(0, i * 0.1, f"ROI {i+1}: Template Score: {template_score:.4f}, Feature Matches: {feature_score}", fontsize=12)
    
#     plt.axis("off")
#     plt.tight_layout()
#     plt.show()

#     # Decision Logic: Choose the best score
#     best_match_index = np.argmax([score[0] for score in scores])
#     best_template_score = scores[best_match_index][0]
#     best_feature_score = scores[best_match_index][1]

#     # Determine if the best score corresponds to a valid or invalid orientation
#     if best_match_index in [0, 1]:  # Assuming 0 and 1 are valid indices
#         print("Kicker is in a valid orientation.")
#         return True
#     else:
#         print("Kicker is in an invalid orientation.")
#         return False

# # Full pipeline function
# def kicker_pipeline(image_path, valid_roi_paths, threshold=65, white_pixel_threshold_percentage=5):
#     # Step 1: Detect Kicker
#     current_roi, current_edges = detect_kicker(image_path, white_pixel_threshold_percentage=white_pixel_threshold_percentage)
#     if current_roi is None:
#         return False  # No kicker detected

#     # Step 2: Check Orientation if kicker detected
#     return check_kicker_orientation(current_roi, valid_roi_paths)

# # Example usage
# valid_roi_paths = [
#     'Reference_Imgs/valid clean roi.jpg',
#     'Reference_Imgs/valid noisy roi.jpg',
#     'Reference_Imgs/invalid clean roi.jpg',
#     'Reference_Imgs/invalid noisy roi.jpg'
# ]

# result = kicker_pipeline('OneDrive_2024-10-01/Images for Testing/Class 1 - Kicker at front position/cam2024_10_01_10_20_54.jpg', valid_roi_paths)

# %%
# import cv2
# import numpy as np

# # Function to extract the central vertical region from an image
# def extract_vertical_central_region(image, width_ratio=0.3, height_ratio=0.8):
#     height, width = image.shape
#     central_height = int(height * height_ratio)
#     central_width = int(width * width_ratio)
    
#     start_y = (height - central_height) // 2
#     start_x = (width - central_width) // 2
    
#     return image[start_y:start_y + central_height, start_x:start_x + central_width]

# # Function for template matching
# def template_matching(current_central, reference_central):
#     result = cv2.matchTemplate(current_central, reference_central, cv2.TM_CCOEFF_NORMED)
#     match_score = np.max(result)
#     return match_score

# # Function for feature matching using ORB
# def feature_matching(current_central, reference_central):
#     orb = cv2.ORB_create()
#     keypoints1, descriptors1 = orb.detectAndCompute(current_central, None)
#     keypoints2, descriptors2 = orb.detectAndCompute(reference_central, None)

#     # Use BFMatcher for matching
#     bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
#     matches = bf.match(descriptors1, descriptors2)
    
#     return len(matches)  # Number of matches

# # Function to check kicker orientation based on multiple reference images
# def check_kicker_orientation(current_roi, valid_roi_paths, width_ratio=0.3, height_ratio=0.8):
#     # Load all reference ROIs
#     valid_rois = [cv2.imread(path, cv2.IMREAD_GRAYSCALE) for path in valid_roi_paths]
    
#     # Check if any ROI is None
#     if any(roi is None for roi in valid_rois):
#         print("Error: One or more reference ROIs not found.")
#         return False

#     # Extract central vertical regions
#     current_central = extract_vertical_central_region(current_roi, width_ratio, height_ratio)
#     central_regions = [extract_vertical_central_region(roi, width_ratio, height_ratio) for roi in valid_rois]

#     # Initialize scores
#     scores = []

#     # Compare current central region with all reference central regions
#     roi_descriptions = [
#         "clean valid ROI",
#         "noisy valid ROI",
#         "clean invalid ROI",
#         "noisy invalid ROI"
#     ]

#     for i, reference_central in enumerate(central_regions):
#         template_score = template_matching(current_central, reference_central)
#         feature_score = feature_matching(current_central, reference_central)
#         scores.append((template_score, feature_score))
#         print(f"Similarity score with {roi_descriptions[i]}: Template Score: {template_score:.4f}, Feature Matches: {feature_score}")

#     # Decision Logic: Choose the best score
#     best_match_index = np.argmax([score[0] for score in scores])
#     best_template_score = scores[best_match_index][0]
#     best_feature_score = scores[best_match_index][1]

#     # Determine if the best score corresponds to a valid or invalid orientation
#     if best_match_index in [0, 1]:  # Assuming 0 and 1 are valid indices
#         print("Kicker is in a valid orientation.")
#         return True
#     else:
#         print("Kicker is in an invalid orientation.")
#         return False

# # Full pipeline function
# def kicker_pipeline(image_path, valid_roi_paths, threshold=65, white_pixel_threshold_percentage=5):
#     # Step 1: Detect Kicker
#     current_roi, current_edges = detect_kicker(image_path, white_pixel_threshold_percentage=white_pixel_threshold_percentage)
#     if current_roi is None:
#         print("No kicker detected.")
#         return False  # No kicker detected

#     # Step 2: Check Orientation if kicker detected
#     return check_kicker_orientation(current_roi, valid_roi_paths)

# # Example usage
# valid_roi_paths = [
#     'Reference_Imgs/valid clean roi.jpg',
#     'Reference_Imgs/valid noisy roi.jpg',
#     'Reference_Imgs/invalid clean roi.jpg',
#     'Reference_Imgs/invalid noisy roi.jpg'
# ]

# #result = kicker_pipeline('OneDrive_2024-10-01/Images for Testing/Class 1 - Kicker at front position/cam2024_10_01_10_20_54.jpg', valid_roi_paths)

# %%
# import cv2
# import numpy as np

# # Function to extract the central vertical region from an image
# def extract_vertical_central_region(image, width_ratio=0.3, height_ratio=0.8):
#     height, width = image.shape
#     central_height = int(height * height_ratio)
#     central_width = int(width * width_ratio)
    
#     start_y = (height - central_height) // 2
#     start_x = (width - central_width) // 2
    
#     return image[start_y:start_y + central_height, start_x:start_x + central_width]

# # Function for template matching
# def template_matching(current_central, reference_central):
#     result = cv2.matchTemplate(current_central, reference_central, cv2.TM_CCOEFF_NORMED)
#     return np.max(result)

# # Function for feature matching using ORB
# def feature_matching(current_central, reference_central):
#     orb = cv2.ORB_create()
#     keypoints1, descriptors1 = orb.detectAndCompute(current_central, None)
#     keypoints2, descriptors2 = orb.detectAndCompute(reference_central, None)

#     # Use BFMatcher for matching
#     bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
#     matches = bf.match(descriptors1, descriptors2)
    
#     return len(matches)  # Number of matches

# # Combined score calculation with weighted importance
# def combined_score(template_score, feature_score, w_template=0.5, w_feature=0.5):
#     return (w_feature * feature_score) + (w_template * template_score)

# # Function to check kicker orientation based on multiple reference images
# def check_kicker_orientation(current_roi, valid_roi_paths, width_ratio=0.3, height_ratio=0.8):
#     # Load all reference ROIs
#     valid_rois = [cv2.imread(path, cv2.IMREAD_GRAYSCALE) for path in valid_roi_paths]
    
#     if any(roi is None for roi in valid_rois):
#         print("Error: One or more reference ROIs not found.")
#         return False

#     # Extract central vertical regions
#     current_central = extract_vertical_central_region(current_roi, width_ratio, height_ratio)
#     central_regions = [extract_vertical_central_region(roi, width_ratio, height_ratio) for roi in valid_rois]

#     roi_descriptions = [
#         "clean valid ROI",
#         "noisy valid ROI",
#         "clean invalid ROI",
#         "noisy invalid ROI"
#     ]

#     # Calculate scores for each reference ROI
#     scores = []
#     for i, reference_central in enumerate(central_regions):
#         template_score = template_matching(current_central, reference_central)
#         feature_score = feature_matching(current_central, reference_central)
#         combined = combined_score(template_score, feature_score)
#         scores.append(combined)
#         print(f"ROI {roi_descriptions[i]} - Combined Score: {combined:.4f}, Template Score: {template_score:.4f}, Feature Matches: {feature_score}")

#     # Find the best match (highest combined score)
#     best_match_index = np.argmax(scores)
#     best_score = scores[best_match_index]

#     # Decision based on threshold
#     threshold = 20  # You can adjust this threshold based on testing
#     if best_score > threshold:
#         if best_match_index in [0, 1]:  # Valid ROIs
#             print(f"Kicker is in valid orientation (matched with {roi_descriptions[best_match_index]}).")
#             return True
#         else:
#             print(f"Kicker is in invalid orientation (matched with {roi_descriptions[best_match_index]}).")
#             return False
#     else:
#         print("No clear valid match, kicker might be in invalid orientation.")
#         return False

# # Full pipeline function
# def kicker_pipeline(image_path, valid_roi_paths, white_pixel_threshold_percentage=5):
#     # Step 1: Detect Kicker
#     current_roi, current_edges = detect_kicker(image_path, white_pixel_threshold_percentage=white_pixel_threshold_percentage)
#     if current_roi is None:
#         print("No kicker detected.")
#         return False  # No kicker detected

#     # Step 2: Check Orientation if kicker detected
#     return check_kicker_orientation(current_roi, valid_roi_paths)

# # Example usage
# valid_roi_paths = [
#     'Reference_Imgs/valid clean roi.jpg',
#     'Reference_Imgs/valid noisy roi.jpg',
#     'Reference_Imgs/invalid clean roi.jpg',
#     'Reference_Imgs/invalid noisy roi.jpg'
# ]

# #result = kicker_pipeline('OneDrive_2024-10-01/Images for Testing/Class 1 - Kicker at front position/cam2024_10_01_10_20_54.jpg', valid_roi_paths)

# %%
# import cv2
# import numpy as np

# # Function to extract the central vertical region from an image
# def extract_vertical_central_region(image, width_ratio=0.3, height_ratio=0.8):
#     height, width = image.shape
#     central_height = int(height * height_ratio)
#     central_width = int(width * width_ratio)
    
#     start_y = (height - central_height) // 2
#     start_x = (width - central_width) // 2
    
#     return image[start_y:start_y + central_height, start_x:start_x + central_width]

# # Function for template matching
# def template_matching(current_central, reference_central):
#     result = cv2.matchTemplate(current_central, reference_central, cv2.TM_CCOEFF_NORMED)
#     return np.max(result)

# # Function for feature matching using ORB
# def feature_matching(current_central, reference_central):
#     orb = cv2.ORB_create()
#     keypoints1, descriptors1 = orb.detectAndCompute(current_central, None)
#     keypoints2, descriptors2 = orb.detectAndCompute(reference_central, None)

#     if descriptors1 is None or descriptors2 is None:
#         return 0  # Return 0 if no descriptors found

#     # Use BFMatcher for matching
#     bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
#     matches = bf.match(descriptors1, descriptors2)
    
#     return len(matches)  # Number of matches

# # Combined score calculation with weighted importance
# def combined_score(template_score, feature_score, w_template=0.5, w_feature=0.5):
#     return (w_feature * feature_score) + (w_template * template_score)

# # Function to check kicker orientation based on multiple reference images
# def check_kicker_orientation(current_roi, valid_roi_paths, width_ratio=0.3, height_ratio=0.8):
#     # Load all reference ROIs
#     valid_rois = [cv2.imread(path, cv2.IMREAD_GRAYSCALE) for path in valid_roi_paths]
    
#     if any(roi is None for roi in valid_rois):
#         print("Error: One or more reference ROIs not found.")
#         return False

#     # Extract central vertical regions
#     current_central = extract_vertical_central_region(current_roi, width_ratio, height_ratio)
#     central_regions = [extract_vertical_central_region(roi, width_ratio, height_ratio) for roi in valid_rois]

#     roi_descriptions = [
#         "clean valid ROI",
#         "noisy valid ROI",
#         "clean invalid ROI",
#         "noisy invalid ROI"
#     ]

#     # Calculate scores for each reference ROI
#     valid_scores = []
#     invalid_scores = []
    
#     for i, reference_central in enumerate(central_regions):
#         template_score = template_matching(current_central, reference_central)
#         feature_score = feature_matching(current_central, reference_central)
#         combined = combined_score(template_score, feature_score)

#         if i in [0, 1]:  # Valid ROIs
#             valid_scores.append(combined)
#         else:  # Invalid ROIs
#             invalid_scores.append(combined)

#         print(f"ROI {roi_descriptions[i]} - Combined Score: {combined:.4f}, Template Score: {template_score:.4f}, Feature Matches: {feature_score}")

#     # Aggregate valid and invalid scores
#     total_valid_score = sum(valid_scores)
#     total_invalid_score = sum(invalid_scores)

#     print(f"Total Valid Score: {total_valid_score:.4f}, Total Invalid Score: {total_invalid_score:.4f}")

#     # Decision Logic: Compare aggregated scores
#     if total_valid_score > total_invalid_score:
#         print("Kicker is in valid orientation.")
#         return True
#     else:
#         print("Kicker is in invalid orientation.")
#         return False

# # Full pipeline function
# def kicker_pipeline(image_path, valid_roi_paths, white_pixel_threshold_percentage=5):
#     # Step 1: Detect Kicker
#     current_roi, current_edges = detect_kicker(image_path, white_pixel_threshold_percentage=white_pixel_threshold_percentage)
#     if current_roi is None:
#         print("No kicker detected.")
#         return False  # No kicker detected

#     # Step 2: Check Orientation if kicker detected
#     return check_kicker_orientation(current_roi, valid_roi_paths)

# # Example usage
# valid_roi_paths = [
#     'Reference_Imgs/valid clean roi.jpg',
#     'Reference_Imgs/valid noisy roi.jpg',
#     'Reference_Imgs/invalid clean roi.jpg',
#     'Reference_Imgs/invalid noisy roi.jpg'
# ]

# #result = kicker_pipeline('OneDrive_2024-10-01/Images for Testing/Class 1 - Kicker at front position/cam2024_10_01_10_20_54.jpg', valid_roi_paths)

# %% [markdown]
# ## updated approach

# %%
import cv2
import numpy as np

# Function to extract the central vertical region from an image
def extract_vertical_central_region(image, width_ratio=0.3, height_ratio=0.8):
    height, width = image.shape
    central_height = int(height * height_ratio)
    central_width = int(width * width_ratio)
    
    start_y = (height - central_height) // 2
    start_x = (width - central_width) // 2
    
    return image[start_y:start_y + central_height, start_x:start_x + central_width]

# Function for template matching
def template_matching(current_central, reference_central):
    result = cv2.matchTemplate(current_central, reference_central, cv2.TM_CCOEFF_NORMED)
    return np.max(result)

# Function for feature matching using ORB
def feature_matching(current_central, reference_central):
    orb = cv2.ORB_create()
    keypoints1, descriptors1 = orb.detectAndCompute(current_central, None)
    keypoints2, descriptors2 = orb.detectAndCompute(reference_central, None)

    # Use BFMatcher for matching
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(descriptors1, descriptors2)
    
    return len(matches)  # Number of matches

# Function for histogram comparison
def histogram_comparison(current_central, reference_central):
    # Calculate histogram for both images
    hist_current = cv2.calcHist([current_central], [0], None, [256], [0, 256])
    hist_reference = cv2.calcHist([reference_central], [0], None, [256], [0, 256])

    # Normalize histograms
    hist_current = cv2.normalize(hist_current, hist_current)
    hist_reference = cv2.normalize(hist_reference, hist_reference)

    # Compare histograms using Chi-Square distance
    hist_score = cv2.compareHist(hist_current, hist_reference, cv2.HISTCMP_CHISQR)
    
    # Invert the score so that higher values represent better matches (since lower Chi-Square is better)
    return 1 / (1 + hist_score)  # This gives a score between 0 and 1

# Combined score calculation with weighted importance
def combined_score(template_score, feature_score, hist_score, w_template=0.4, w_feature=0.4, w_hist=0.2):
    return (w_template * template_score) + (w_feature * feature_score) + (w_hist * hist_score)

# Function to check kicker orientation based on multiple reference images
def check_kicker_orientation(current_roi, valid_roi_paths, width_ratio=0.3, height_ratio=0.8):
    # Load all reference ROIs
    valid_rois = [cv2.imread(path, cv2.IMREAD_GRAYSCALE) for path in valid_roi_paths]
    
    if any(roi is None for roi in valid_rois):
        print("Error: One or more reference ROIs not found.")
        return False

    # Extract central vertical regions
    current_central = extract_vertical_central_region(current_roi, width_ratio, height_ratio)
    central_regions = [extract_vertical_central_region(roi, width_ratio, height_ratio) for roi in valid_rois]

    roi_descriptions = [
        "clean valid ROI",
        "noisy valid ROI",
        "clean invalid ROI",
        "noisy invalid ROI"
    ]

    # Calculate scores for each reference ROI
    scores = []
    for i, reference_central in enumerate(central_regions):
        template_score = template_matching(current_central, reference_central)
        feature_score = feature_matching(current_central, reference_central)
        hist_score = histogram_comparison(current_central, reference_central)
        
        combined = combined_score(template_score, feature_score, hist_score)
        scores.append(combined)
        print(f"ROI {roi_descriptions[i]} - Combined Score: {combined:.4f}, Template Score: {template_score:.4f}, Feature Matches: {feature_score}, Histogram Score: {hist_score:.4f}")

    # Find the best match (highest combined score)
    best_match_index = np.argmax(scores)
    best_score = scores[best_match_index]

    # Decision based on threshold
    threshold = 20  # You can adjust this threshold based on testing
    if best_score > threshold:
        if best_match_index in [0, 1]:  # Valid ROIs
            print(f"Kicker is in valid orientation (matched with {roi_descriptions[best_match_index]}).")
            return True
        else:
            print(f"Kicker is in invalid orientation (matched with {roi_descriptions[best_match_index]}).")
            return False
    else:
        print("No clear valid match, kicker might be in invalid orientation.")
        return False

# Full pipeline function
def kicker_pipeline(image_path, valid_roi_paths, white_pixel_threshold_percentage=5):
    # Step 1: Detect Kicker
    current_roi, current_edges = detect_kicker(image_path, white_pixel_threshold_percentage=white_pixel_threshold_percentage)
    if current_roi is None:
        print("No kicker detected.")
        return False  # No kicker detected

    # Step 2: Check Orientation if kicker detected
    return check_kicker_orientation(current_roi, valid_roi_paths)

# Example usage
valid_roi_paths = [
    'Reference_Imgs/valid clean roi.jpg',
    'Reference_Imgs/valid noisy roi.jpg',
    'Reference_Imgs/invalid clean roi.jpg',
    'Reference_Imgs/invalid noisy roi.jpg'
]

# result = kicker_pipeline('OneDrive_2024-10-01/Images for Testing/Class 1 - Kicker at front position/cam2024_10_01_10_20_54.jpg', valid_roi_paths)

# %% [markdown]
# # Inference  (Ground Truth = Kicker Detected and in Valid Position)

# %%
import os
import shutil

def process_folder(folder_path, reference_roi_paths, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through all the images in the folder
    for image_filename in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_filename)

        # Check if the file is an image (based on its extension)
        if image_filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            # Run the pipeline on the image to check orientation
            valid_orientation = kicker_pipeline(image_path, reference_roi_paths)

            # If kicker is in an invalid orientation, move the image to the output folder
            if not valid_orientation:
                print(f"Moving {image_filename} to '{output_folder}' (invalid kicker detected).")
                shutil.copy(image_path, os.path.join(output_folder, image_filename))
            else:
                print(f"{image_filename} is valid (kicker in correct orientation).")

        print("----------------------------------------------------------------------\n\n")

# Example usage
folder_path = 'Classes/class_0'
reference_roi_paths = [
    'Reference_Imgs/valid clean roi.jpg',
    'Reference_Imgs/valid noisy roi.jpg',
    'Reference_Imgs/invalid clean roi.jpg',
    'Reference_Imgs/invalid noisy roi.jpg'
]
output_folder = 'False_images_class0'

print("----------------------------------------------------------------------\n\n")
process_folder(folder_path, reference_roi_paths, output_folder)
# Out:
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 16.43%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 28.6051, Template Score: 0.0127, Feature Matches: 71, Histogram Score: 1.0000
# ROI noisy valid ROI - Combined Score: 25.3985, Template Score: -0.0035, Feature Matches: 63, Histogram Score: 0.9995
# ROI clean invalid ROI - Combined Score: 20.6075, Template Score: 0.0201, Feature Matches: 51, Histogram Score: 0.9971
# ROI noisy invalid ROI - Combined Score: 25.4070, Template Score: 0.0175, Feature Matches: 63, Histogram Score: 0.9998
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_17_44_30.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 31.37%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 42.5981, Template Score: 0.0016, Feature Matches: 106, Histogram Score: 0.9875
# ROI noisy valid ROI - Combined Score: 41.0015, Template Score: 0.0085, Feature Matches: 102, Histogram Score: 0.9906
# ROI clean invalid ROI - Combined Score: 26.9981, Template Score: 0.0064, Feature Matches: 67, Histogram Score: 0.9779
# ROI noisy invalid ROI - Combined Score: 27.0027, Template Score: 0.0141, Feature Matches: 67, Histogram Score: 0.9853
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_40_02.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.20%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 40.5999, Template Score: 0.0011, Feature Matches: 101, Histogram Score: 0.9973
# ROI noisy valid ROI - Combined Score: 34.6000, Template Score: 0.0007, Feature Matches: 86, Histogram Score: 0.9989
# ROI clean invalid ROI - Combined Score: 23.8021, Template Score: 0.0100, Feature Matches: 59, Histogram Score: 0.9906
# ROI noisy invalid ROI - Combined Score: 27.0062, Template Score: 0.0174, Feature Matches: 67, Histogram Score: 0.9960
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_10_35_48.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 24.12%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 35.3996, Template Score: 0.0003, Feature Matches: 88, Histogram Score: 0.9973
# ROI noisy valid ROI - Combined Score: 34.6100, Template Score: 0.0255, Feature Matches: 86, Histogram Score: 0.9989
# ROI clean invalid ROI - Combined Score: 25.7962, Template Score: -0.0049, Feature Matches: 64, Histogram Score: 0.9906
# ROI noisy invalid ROI - Combined Score: 28.6004, Template Score: 0.0031, Feature Matches: 71, Histogram Score: 0.9960
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_14_19_58.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 21.13%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 27.4002, Template Score: 0.0012, Feature Matches: 68, Histogram Score: 0.9987
# ROI noisy valid ROI - Combined Score: 28.2068, Template Score: 0.0170, Feature Matches: 70, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 23.8003, Template Score: 0.0044, Feature Matches: 59, Histogram Score: 0.9930
# ROI noisy invalid ROI - Combined Score: 21.8003, Template Score: 0.0018, Feature Matches: 54, Histogram Score: 0.9977
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_17_02_11.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 16.55%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 35.4063, Template Score: 0.0165, Feature Matches: 88, Histogram Score: 0.9985
# ROI noisy valid ROI - Combined Score: 39.0059, Template Score: 0.0149, Feature Matches: 97, Histogram Score: 0.9996
# ROI clean invalid ROI - Combined Score: 23.4013, Template Score: 0.0069, Feature Matches: 58, Histogram Score: 0.9925
# ROI noisy invalid ROI - Combined Score: 25.4036, Template Score: 0.0103, Feature Matches: 63, Histogram Score: 0.9974
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_27_12_00_23.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.85%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 33.0013, Template Score: 0.0053, Feature Matches: 82, Histogram Score: 0.9956
# ROI noisy valid ROI - Combined Score: 36.2030, Template Score: 0.0087, Feature Matches: 90, Histogram Score: 0.9976
# ROI clean invalid ROI - Combined Score: 24.1980, Template Score: 0.0009, Feature Matches: 60, Histogram Score: 0.9881
# ROI noisy invalid ROI - Combined Score: 24.2008, Template Score: 0.0050, Feature Matches: 60, Histogram Score: 0.9940
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_14_15_46.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.50%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 37.7990, Template Score: -0.0017, Feature Matches: 94, Histogram Score: 0.9985
# ROI noisy valid ROI - Combined Score: 36.2017, Template Score: 0.0044, Feature Matches: 90, Histogram Score: 0.9996
# ROI clean invalid ROI - Combined Score: 23.8056, Template Score: 0.0178, Feature Matches: 59, Histogram Score: 0.9926
# ROI noisy invalid ROI - Combined Score: 27.7962, Template Score: -0.0083, Feature Matches: 69, Histogram Score: 0.9974
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_20_51.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 25.10%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 32.9985, Template Score: -0.0017, Feature Matches: 82, Histogram Score: 0.9960
# ROI noisy valid ROI - Combined Score: 33.4059, Template Score: 0.0158, Feature Matches: 83, Histogram Score: 0.9980
# ROI clean invalid ROI - Combined Score: 25.4040, Template Score: 0.0157, Feature Matches: 63, Histogram Score: 0.9887
# ROI noisy invalid ROI - Combined Score: 30.5962, Template Score: -0.0068, Feature Matches: 76, Histogram Score: 0.9945
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_18_03_32.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 21.98%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 33.7965, Template Score: -0.0074, Feature Matches: 84, Histogram Score: 0.9972
# ROI noisy valid ROI - Combined Score: 30.6068, Template Score: 0.0176, Feature Matches: 76, Histogram Score: 0.9988
# ROI clean invalid ROI - Combined Score: 25.8035, Template Score: 0.0135, Feature Matches: 64, Histogram Score: 0.9904
# ROI noisy invalid ROI - Combined Score: 26.6048, Template Score: 0.0141, Feature Matches: 66, Histogram Score: 0.9959
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_16_21.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 13.87%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 36.2069, Template Score: 0.0172, Feature Matches: 90, Histogram Score: 1.0000
# ROI noisy valid ROI - Combined Score: 32.1975, Template Score: -0.0062, Feature Matches: 80, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 24.2049, Template Score: 0.0140, Feature Matches: 60, Histogram Score: 0.9967
# ROI noisy invalid ROI - Combined Score: 26.5992, Template Score: -0.0019, Feature Matches: 66, Histogram Score: 0.9997
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_25_19.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.44%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 35.4023, Template Score: 0.0065, Feature Matches: 88, Histogram Score: 0.9986
# ROI noisy valid ROI - Combined Score: 35.4021, Template Score: 0.0054, Feature Matches: 88, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 25.8011, Template Score: 0.0064, Feature Matches: 64, Histogram Score: 0.9927
# ROI noisy invalid ROI - Combined Score: 27.0065, Template Score: 0.0176, Feature Matches: 67, Histogram Score: 0.9975
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_10_31_23.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 34.86%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 44.5964, Template Score: -0.0019, Feature Matches: 111, Histogram Score: 0.9860
# ROI noisy valid ROI - Combined Score: 48.1989, Template Score: 0.0027, Feature Matches: 120, Histogram Score: 0.9893
# ROI clean invalid ROI - Combined Score: 29.7990, Template Score: 0.0093, Feature Matches: 74, Histogram Score: 0.9762
# ROI noisy invalid ROI - Combined Score: 24.2047, Template Score: 0.0200, Feature Matches: 60, Histogram Score: 0.9838
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_37_17.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.68%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 41.8017, Template Score: 0.0045, Feature Matches: 104, Histogram Score: 0.9998
# ROI noisy valid ROI - Combined Score: 34.2062, Template Score: 0.0155, Feature Matches: 85, Histogram Score: 0.9999
# ROI clean invalid ROI - Combined Score: 27.8038, Template Score: 0.0116, Feature Matches: 69, Histogram Score: 0.9958
# ROI noisy invalid ROI - Combined Score: 27.4002, Template Score: 0.0007, Feature Matches: 68, Histogram Score: 0.9993
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_10_27_02.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 32.11%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 41.7967, Template Score: -0.0012, Feature Matches: 104, Histogram Score: 0.9857
# ROI noisy valid ROI - Combined Score: 38.5993, Template Score: 0.0038, Feature Matches: 96, Histogram Score: 0.9891
# ROI clean invalid ROI - Combined Score: 22.5957, Template Score: 0.0013, Feature Matches: 56, Histogram Score: 0.9760
# ROI noisy invalid ROI - Combined Score: 27.0034, Template Score: 0.0167, Feature Matches: 67, Histogram Score: 0.9835
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_41_35.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 20.13%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 32.6000, Template Score: 0.0014, Feature Matches: 81, Histogram Score: 0.9972
# ROI noisy valid ROI - Combined Score: 32.6066, Template Score: 0.0170, Feature Matches: 81, Histogram Score: 0.9988
# ROI clean invalid ROI - Combined Score: 23.3975, Template Score: -0.0014, Feature Matches: 58, Histogram Score: 0.9904
# ROI noisy invalid ROI - Combined Score: 24.2011, Template Score: 0.0047, Feature Matches: 60, Histogram Score: 0.9958
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_14_18_50.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 22.05%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 37.3982, Template Score: -0.0037, Feature Matches: 93, Histogram Score: 0.9984
# ROI noisy valid ROI - Combined Score: 35.0029, Template Score: 0.0076, Feature Matches: 87, Histogram Score: 0.9996
# ROI clean invalid ROI - Combined Score: 21.7997, Template Score: 0.0031, Feature Matches: 54, Histogram Score: 0.9925
# ROI noisy invalid ROI - Combined Score: 30.9979, Template Score: -0.0040, Feature Matches: 77, Histogram Score: 0.9974
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_17_01_01.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 16.97%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 34.6052, Template Score: 0.0129, Feature Matches: 86, Histogram Score: 1.0000
# ROI noisy valid ROI - Combined Score: 33.0068, Template Score: 0.0174, Feature Matches: 82, Histogram Score: 0.9994
# ROI clean invalid ROI - Combined Score: 23.0037, Template Score: 0.0107, Feature Matches: 57, Histogram Score: 0.9972
# ROI noisy invalid ROI - Combined Score: 24.2076, Template Score: 0.0192, Feature Matches: 60, Histogram Score: 0.9998
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_12_02_15.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 25.66%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 34.9989, Template Score: -0.0017, Feature Matches: 87, Histogram Score: 0.9980
# ROI noisy valid ROI - Combined Score: 33.4068, Template Score: 0.0173, Feature Matches: 83, Histogram Score: 0.9994
# ROI clean invalid ROI - Combined Score: 28.2035, Template Score: 0.0128, Feature Matches: 70, Histogram Score: 0.9917
# ROI noisy invalid ROI - Combined Score: 28.5959, Template Score: -0.0086, Feature Matches: 71, Histogram Score: 0.9968
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_06_58.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 34.55%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 41.7989, Template Score: 0.0046, Feature Matches: 104, Histogram Score: 0.9853
# ROI noisy valid ROI - Combined Score: 47.3962, Template Score: -0.0039, Feature Matches: 118, Histogram Score: 0.9887
# ROI clean invalid ROI - Combined Score: 21.7956, Template Score: 0.0014, Feature Matches: 54, Histogram Score: 0.9755
# ROI noisy invalid ROI - Combined Score: 25.0063, Template Score: 0.0242, Feature Matches: 62, Histogram Score: 0.9831
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_36_31.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 17.81%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 36.2024, Template Score: 0.0063, Feature Matches: 90, Histogram Score: 0.9994
# ROI noisy valid ROI - Combined Score: 39.8037, Template Score: 0.0093, Feature Matches: 99, Histogram Score: 1.0000
# ROI clean invalid ROI - Combined Score: 22.6009, Template Score: 0.0048, Feature Matches: 56, Histogram Score: 0.9946
# ROI noisy invalid ROI - Combined Score: 27.8044, Template Score: 0.0115, Feature Matches: 69, Histogram Score: 0.9987
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_09_04.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.20%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 33.4024, Template Score: 0.0060, Feature Matches: 83, Histogram Score: 0.9997
# ROI noisy valid ROI - Combined Score: 31.0012, Template Score: 0.0029, Feature Matches: 77, Histogram Score: 1.0000
# ROI clean invalid ROI - Combined Score: 23.8035, Template Score: 0.0110, Feature Matches: 59, Histogram Score: 0.9955
# ROI noisy invalid ROI - Combined Score: 25.8004, Template Score: 0.0015, Feature Matches: 64, Histogram Score: 0.9992
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_07_36.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.33%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 37.7995, Template Score: 0.0006, Feature Matches: 94, Histogram Score: 0.9964
# ROI noisy valid ROI - Combined Score: 35.3991, Template Score: -0.0013, Feature Matches: 88, Histogram Score: 0.9982
# ROI clean invalid ROI - Combined Score: 23.4020, Template Score: 0.0105, Feature Matches: 58, Histogram Score: 0.9892
# ROI noisy invalid ROI - Combined Score: 22.6111, Template Score: 0.0303, Feature Matches: 56, Histogram Score: 0.9949
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_10_35_55.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 21.51%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 40.9996, Template Score: 0.0008, Feature Matches: 102, Histogram Score: 0.9964
# ROI noisy valid ROI - Combined Score: 38.2010, Template Score: 0.0033, Feature Matches: 95, Histogram Score: 0.9983
# ROI clean invalid ROI - Combined Score: 22.9987, Template Score: 0.0021, Feature Matches: 57, Histogram Score: 0.9893
# ROI noisy invalid ROI - Combined Score: 27.4090, Template Score: 0.0251, Feature Matches: 68, Histogram Score: 0.9950
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_10_39_20.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.56%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 34.5976, Template Score: -0.0052, Feature Matches: 86, Histogram Score: 0.9986
# ROI noisy valid ROI - Combined Score: 33.8048, Template Score: 0.0122, Feature Matches: 84, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 22.6024, Template Score: 0.0095, Feature Matches: 56, Histogram Score: 0.9927
# ROI noisy invalid ROI - Combined Score: 24.1965, Template Score: -0.0074, Feature Matches: 60, Histogram Score: 0.9975
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_14_42.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 24.42%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 28.1999, Template Score: 0.0005, Feature Matches: 70, Histogram Score: 0.9986
# ROI noisy valid ROI - Combined Score: 35.4091, Template Score: 0.0228, Feature Matches: 88, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 26.2015, Template Score: 0.0074, Feature Matches: 65, Histogram Score: 0.9929
# ROI noisy invalid ROI - Combined Score: 29.7956, Template Score: -0.0098, Feature Matches: 74, Histogram Score: 0.9976
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_18_07_15.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.69%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 37.7987, Template Score: -0.0013, Feature Matches: 94, Histogram Score: 0.9963
# ROI noisy valid ROI - Combined Score: 40.1994, Template Score: -0.0006, Feature Matches: 100, Histogram Score: 0.9982
# ROI clean invalid ROI - Combined Score: 26.5985, Template Score: 0.0017, Feature Matches: 66, Histogram Score: 0.9891
# ROI noisy invalid ROI - Combined Score: 27.0043, Template Score: 0.0133, Feature Matches: 67, Histogram Score: 0.9949
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_14_12_46.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 25.60%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 32.9988, Template Score: -0.0018, Feature Matches: 82, Histogram Score: 0.9976
# ROI noisy valid ROI - Combined Score: 33.0068, Template Score: 0.0174, Feature Matches: 82, Histogram Score: 0.9991
# ROI clean invalid ROI - Combined Score: 27.8010, Template Score: 0.0069, Feature Matches: 69, Histogram Score: 0.9911
# ROI noisy invalid ROI - Combined Score: 22.9973, Template Score: -0.0049, Feature Matches: 57, Histogram Score: 0.9964
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_18_03_50.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 20.11%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 35.4024, Template Score: 0.0083, Feature Matches: 88, Histogram Score: 0.9953
# ROI noisy valid ROI - Combined Score: 32.2020, Template Score: 0.0064, Feature Matches: 80, Histogram Score: 0.9974
# ROI clean invalid ROI - Combined Score: 21.7977, Template Score: 0.0004, Feature Matches: 54, Histogram Score: 0.9876
# ROI noisy invalid ROI - Combined Score: 23.8005, Template Score: 0.0044, Feature Matches: 59, Histogram Score: 0.9937
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_14_17_22.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.14%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 35.8037, Template Score: 0.0121, Feature Matches: 89, Histogram Score: 0.9943
# ROI noisy valid ROI - Combined Score: 30.2060, Template Score: 0.0167, Feature Matches: 75, Histogram Score: 0.9966
# ROI clean invalid ROI - Combined Score: 24.5997, Template Score: 0.0062, Feature Matches: 61, Histogram Score: 0.9863
# ROI noisy invalid ROI - Combined Score: 24.1998, Template Score: 0.0031, Feature Matches: 60, Histogram Score: 0.9926
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_18_23.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.75%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 39.4020, Template Score: 0.0065, Feature Matches: 98, Histogram Score: 0.9968
# ROI noisy valid ROI - Combined Score: 37.8011, Template Score: 0.0035, Feature Matches: 94, Histogram Score: 0.9986
# ROI clean invalid ROI - Combined Score: 19.0007, Template Score: 0.0070, Feature Matches: 47, Histogram Score: 0.9898
# ROI noisy invalid ROI - Combined Score: 27.4005, Template Score: 0.0036, Feature Matches: 68, Histogram Score: 0.9954
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_16_56.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 20.54%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 38.6015, Template Score: 0.0043, Feature Matches: 96, Histogram Score: 0.9989
# ROI noisy valid ROI - Combined Score: 42.2032, Template Score: 0.0080, Feature Matches: 105, Histogram Score: 0.9998
# ROI clean invalid ROI - Combined Score: 29.0016, Template Score: 0.0073, Feature Matches: 72, Histogram Score: 0.9934
# ROI noisy invalid ROI - Combined Score: 28.1941, Template Score: -0.0139, Feature Matches: 70, Histogram Score: 0.9980
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_18_21_24.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 30.34%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 41.3993, Template Score: 0.0051, Feature Matches: 103, Histogram Score: 0.9861
# ROI noisy valid ROI - Combined Score: 46.6005, Template Score: 0.0064, Feature Matches: 116, Histogram Score: 0.9895
# ROI clean invalid ROI - Combined Score: 26.1974, Template Score: 0.0052, Feature Matches: 65, Histogram Score: 0.9764
# ROI noisy invalid ROI - Combined Score: 24.6045, Template Score: 0.0192, Feature Matches: 61, Histogram Score: 0.9839
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_35_33.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 28.09%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 37.0027, Template Score: 0.0083, Feature Matches: 92, Histogram Score: 0.9969
# ROI noisy valid ROI - Combined Score: 37.8024, Template Score: 0.0068, Feature Matches: 94, Histogram Score: 0.9986
# ROI clean invalid ROI - Combined Score: 24.6002, Template Score: 0.0056, Feature Matches: 61, Histogram Score: 0.9900
# ROI noisy invalid ROI - Combined Score: 26.9950, Template Score: -0.0103, Feature Matches: 67, Histogram Score: 0.9955
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_18_00_47.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 24.77%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 41.3991, Template Score: -0.0011, Feature Matches: 103, Histogram Score: 0.9977
# ROI noisy valid ROI - Combined Score: 32.6047, Template Score: 0.0122, Feature Matches: 81, Histogram Score: 0.9992
# ROI clean invalid ROI - Combined Score: 25.4023, Template Score: 0.0100, Feature Matches: 63, Histogram Score: 0.9913
# ROI noisy invalid ROI - Combined Score: 24.5979, Template Score: -0.0034, Feature Matches: 61, Histogram Score: 0.9965
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_04_27.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 16.96%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 37.0015, Template Score: 0.0036, Feature Matches: 92, Histogram Score: 1.0000
# ROI noisy valid ROI - Combined Score: 28.6127, Template Score: 0.0321, Feature Matches: 71, Histogram Score: 0.9995
# ROI clean invalid ROI - Combined Score: 23.0029, Template Score: 0.0087, Feature Matches: 57, Histogram Score: 0.9971
# ROI noisy invalid ROI - Combined Score: 22.1982, Template Score: -0.0044, Feature Matches: 55, Histogram Score: 0.9998
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_16_54_52.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 25.16%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 34.9995, Template Score: -0.0005, Feature Matches: 87, Histogram Score: 0.9987
# ROI noisy valid ROI - Combined Score: 33.8071, Template Score: 0.0179, Feature Matches: 84, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 24.6050, Template Score: 0.0161, Feature Matches: 61, Histogram Score: 0.9930
# ROI noisy invalid ROI - Combined Score: 25.3980, Template Score: -0.0038, Feature Matches: 63, Histogram Score: 0.9977
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_07_33.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.98%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 33.0025, Template Score: 0.0077, Feature Matches: 82, Histogram Score: 0.9968
# ROI noisy valid ROI - Combined Score: 38.6018, Template Score: 0.0052, Feature Matches: 96, Histogram Score: 0.9986
# ROI clean invalid ROI - Combined Score: 25.0005, Template Score: 0.0062, Feature Matches: 62, Histogram Score: 0.9899
# ROI noisy invalid ROI - Combined Score: 24.2013, Template Score: 0.0055, Feature Matches: 60, Histogram Score: 0.9955
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_19_41.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 22.17%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 33.0005, Template Score: 0.0024, Feature Matches: 82, Histogram Score: 0.9979
# ROI noisy valid ROI - Combined Score: 39.0028, Template Score: 0.0074, Feature Matches: 97, Histogram Score: 0.9993
# ROI clean invalid ROI - Combined Score: 22.6019, Template Score: 0.0089, Feature Matches: 56, Histogram Score: 0.9916
# ROI noisy invalid ROI - Combined Score: 28.5997, Template Score: 0.0008, Feature Matches: 71, Histogram Score: 0.9967
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_18_18_59.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 16.48%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 36.6087, Template Score: 0.0217, Feature Matches: 91, Histogram Score: 1.0000
# ROI noisy valid ROI - Combined Score: 31.8038, Template Score: 0.0096, Feature Matches: 79, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 25.8056, Template Score: 0.0156, Feature Matches: 64, Histogram Score: 0.9966
# ROI noisy invalid ROI - Combined Score: 27.4142, Template Score: 0.0356, Feature Matches: 68, Histogram Score: 0.9997
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_12_02_20.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 22.56%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 39.7987, Template Score: 0.0007, Feature Matches: 99, Histogram Score: 0.9924
# ROI noisy valid ROI - Combined Score: 41.4026, Template Score: 0.0091, Feature Matches: 103, Histogram Score: 0.9950
# ROI clean invalid ROI - Combined Score: 25.7970, Template Score: 0.0006, Feature Matches: 64, Histogram Score: 0.9838
# ROI noisy invalid ROI - Combined Score: 22.1943, Template Score: -0.0095, Feature Matches: 55, Histogram Score: 0.9905
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_14_12_03.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 24.62%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 34.2032, Template Score: 0.0092, Feature Matches: 85, Histogram Score: 0.9975
# ROI noisy valid ROI - Combined Score: 33.4002, Template Score: 0.0011, Feature Matches: 83, Histogram Score: 0.9990
# ROI clean invalid ROI - Combined Score: 24.2017, Template Score: 0.0088, Feature Matches: 60, Histogram Score: 0.9909
# ROI noisy invalid ROI - Combined Score: 26.1988, Template Score: -0.0012, Feature Matches: 65, Histogram Score: 0.9962
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_17_39.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 25.26%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 36.6012, Template Score: 0.0039, Feature Matches: 91, Histogram Score: 0.9983
# ROI noisy valid ROI - Combined Score: 33.4069, Template Score: 0.0176, Feature Matches: 83, Histogram Score: 0.9995
# ROI clean invalid ROI - Combined Score: 25.0014, Template Score: 0.0074, Feature Matches: 62, Histogram Score: 0.9923
# ROI noisy invalid ROI - Combined Score: 29.7972, Template Score: -0.0055, Feature Matches: 74, Histogram Score: 0.9972
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_09_19.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 18.63%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 33.3995, Template Score: -0.0004, Feature Matches: 83, Histogram Score: 0.9982
# ROI noisy valid ROI - Combined Score: 37.4060, Template Score: 0.0152, Feature Matches: 93, Histogram Score: 0.9995
# ROI clean invalid ROI - Combined Score: 24.6065, Template Score: 0.0202, Feature Matches: 61, Histogram Score: 0.9921
# ROI noisy invalid ROI - Combined Score: 27.3949, Template Score: -0.0113, Feature Matches: 68, Histogram Score: 0.9971
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_17_03_49.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.18%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 41.8026, Template Score: 0.0086, Feature Matches: 104, Histogram Score: 0.9958
# ROI noisy valid ROI - Combined Score: 41.8028, Template Score: 0.0080, Feature Matches: 104, Histogram Score: 0.9978
# ROI clean invalid ROI - Combined Score: 25.7984, Template Score: 0.0018, Feature Matches: 64, Histogram Score: 0.9884
# ROI noisy invalid ROI - Combined Score: 24.5982, Template Score: -0.0016, Feature Matches: 61, Histogram Score: 0.9943
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_19_58.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 21.31%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 34.1990, Template Score: 0.0003, Feature Matches: 85, Histogram Score: 0.9945
# ROI noisy valid ROI - Combined Score: 41.8012, Template Score: 0.0046, Feature Matches: 104, Histogram Score: 0.9968
# ROI clean invalid ROI - Combined Score: 23.3968, Template Score: -0.0012, Feature Matches: 58, Histogram Score: 0.9866
# ROI noisy invalid ROI - Combined Score: 23.3978, Template Score: -0.0019, Feature Matches: 58, Histogram Score: 0.9929
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_14_16_03.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.83%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 38.1998, Template Score: 0.0000, Feature Matches: 95, Histogram Score: 0.9987
# ROI noisy valid ROI - Combined Score: 30.6059, Template Score: 0.0150, Feature Matches: 76, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 25.4066, Template Score: 0.0199, Feature Matches: 63, Histogram Score: 0.9930
# ROI noisy invalid ROI - Combined Score: 27.7964, Template Score: -0.0078, Feature Matches: 69, Histogram Score: 0.9977
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_14_23.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 22.72%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 40.6022, Template Score: 0.0070, Feature Matches: 101, Histogram Score: 0.9970
# ROI noisy valid ROI - Combined Score: 36.6041, Template Score: 0.0110, Feature Matches: 91, Histogram Score: 0.9987
# ROI clean invalid ROI - Combined Score: 26.1994, Template Score: 0.0035, Feature Matches: 65, Histogram Score: 0.9901
# ROI noisy invalid ROI - Combined Score: 25.3999, Template Score: 0.0019, Feature Matches: 63, Histogram Score: 0.9957
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_17_13_04.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 21.64%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 35.3994, Template Score: -0.0014, Feature Matches: 88, Histogram Score: 0.9997
# ROI noisy valid ROI - Combined Score: 27.4029, Template Score: 0.0073, Feature Matches: 68, Histogram Score: 1.0000
# ROI clean invalid ROI - Combined Score: 23.0052, Template Score: 0.0152, Feature Matches: 57, Histogram Score: 0.9955
# ROI noisy invalid ROI - Combined Score: 22.5991, Template Score: -0.0018, Feature Matches: 56, Histogram Score: 0.9992
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_10_27_08.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 32.32%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 42.9970, Template Score: -0.0003, Feature Matches: 107, Histogram Score: 0.9856
# ROI noisy valid ROI - Combined Score: 40.2018, Template Score: 0.0100, Feature Matches: 100, Histogram Score: 0.9889
# ROI clean invalid ROI - Combined Score: 26.1987, Template Score: 0.0089, Feature Matches: 65, Histogram Score: 0.9758
# ROI noisy invalid ROI - Combined Score: 25.0026, Template Score: 0.0149, Feature Matches: 62, Histogram Score: 0.9834
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_39_07.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 17.39%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 35.0071, Template Score: 0.0178, Feature Matches: 87, Histogram Score: 1.0000
# ROI noisy valid ROI - Combined Score: 30.2039, Template Score: 0.0099, Feature Matches: 75, Histogram Score: 0.9998
# ROI clean invalid ROI - Combined Score: 24.2016, Template Score: 0.0059, Feature Matches: 60, Histogram Score: 0.9964
# ROI noisy invalid ROI - Combined Score: 26.2054, Template Score: 0.0136, Feature Matches: 65, Histogram Score: 0.9996
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_11_55_25.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 20.00%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 37.0010, Template Score: 0.0043, Feature Matches: 92, Histogram Score: 0.9963
# ROI noisy valid ROI - Combined Score: 43.0013, Template Score: 0.0041, Feature Matches: 107, Histogram Score: 0.9982
# ROI clean invalid ROI - Combined Score: 26.9971, Template Score: -0.0018, Feature Matches: 67, Histogram Score: 0.9891
# ROI noisy invalid ROI - Combined Score: 26.6016, Template Score: 0.0067, Feature Matches: 66, Histogram Score: 0.9949
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_14_17_55.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 28.14%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 41.7950, Template Score: -0.0040, Feature Matches: 104, Histogram Score: 0.9828
# ROI noisy valid ROI - Combined Score: 46.6048, Template Score: 0.0188, Feature Matches: 116, Histogram Score: 0.9863
# ROI clean invalid ROI - Combined Score: 24.9983, Template Score: 0.0095, Feature Matches: 62, Histogram Score: 0.9727
# ROI noisy invalid ROI - Combined Score: 26.6052, Template Score: 0.0228, Feature Matches: 66, Histogram Score: 0.9805
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_34_47.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 18.63%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 31.3970, Template Score: -0.0071, Feature Matches: 78, Histogram Score: 0.9990
# ROI noisy valid ROI - Combined Score: 35.0020, Template Score: 0.0051, Feature Matches: 87, Histogram Score: 0.9999
# ROI clean invalid ROI - Combined Score: 24.2099, Template Score: 0.0280, Feature Matches: 60, Histogram Score: 0.9936
# ROI noisy invalid ROI - Combined Score: 25.7955, Template Score: -0.0104, Feature Matches: 64, Histogram Score: 0.9981
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_17_05_35.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 26.52%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 38.5988, Template Score: 0.0015, Feature Matches: 96, Histogram Score: 0.9910
# ROI noisy valid ROI - Combined Score: 42.2051, Template Score: 0.0157, Feature Matches: 105, Histogram Score: 0.9938
# ROI clean invalid ROI - Combined Score: 24.5983, Template Score: 0.0047, Feature Matches: 61, Histogram Score: 0.9821
# ROI noisy invalid ROI - Combined Score: 30.9985, Template Score: 0.0018, Feature Matches: 77, Histogram Score: 0.9891
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_18_06.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 35.64%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 36.9967, Template Score: -0.0016, Feature Matches: 92, Histogram Score: 0.9867
# ROI noisy valid ROI - Combined Score: 37.0014, Template Score: 0.0085, Feature Matches: 92, Histogram Score: 0.9900
# ROI clean invalid ROI - Combined Score: 24.5984, Template Score: 0.0074, Feature Matches: 61, Histogram Score: 0.9771
# ROI noisy invalid ROI - Combined Score: 24.5977, Template Score: 0.0020, Feature Matches: 61, Histogram Score: 0.9845
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_24_03.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 18.10%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 38.1983, Template Score: -0.0032, Feature Matches: 95, Histogram Score: 0.9979
# ROI noisy valid ROI - Combined Score: 30.2043, Template Score: 0.0111, Feature Matches: 75, Histogram Score: 0.9993
# ...
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 43.7986, Template Score: 0.0041, Feature Matches: 109, Histogram Score: 0.9848
# ROI noisy valid ROI - Combined Score: 44.9998, Template Score: 0.0054, Feature Matches: 112, Histogram Score: 0.9882
# ROI clean invalid ROI - Combined Score: 24.5971, Template Score: 0.0053, Feature Matches: 61, Histogram Score: 0.9749
# ROI noisy invalid ROI - Combined Score: 23.8044, Template Score: 0.0196, Feature Matches: 59, Histogram Score: 0.9826
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_38_24.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.35%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 30.6003, Template Score: 0.0037, Feature Matches: 76, Histogram Score: 0.9942
# ROI noisy valid ROI - Combined Score: 43.0051, Template Score: 0.0145, Feature Matches: 107, Histogram Score: 0.9966
# ROI clean invalid ROI - Combined Score: 23.4033, Template Score: 0.0151, Feature Matches: 58, Histogram Score: 0.9862
# ROI noisy invalid ROI - Combined Score: 21.8041, Template Score: 0.0139, Feature Matches: 54, Histogram Score: 0.9925
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_18_39.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 24.16%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 33.0003, Template Score: 0.0016, Feature Matches: 82, Histogram Score: 0.9981
# ROI noisy valid ROI - Combined Score: 28.6107, Template Score: 0.0270, Feature Matches: 71, Histogram Score: 0.9994
# ROI clean invalid ROI - Combined Score: 22.1979, Template Score: -0.0013, Feature Matches: 55, Histogram Score: 0.9919
# ROI noisy invalid ROI - Combined Score: 23.3978, Template Score: -0.0040, Feature Matches: 58, Histogram Score: 0.9970
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_16_59_27.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.90%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 34.5966, Template Score: -0.0073, Feature Matches: 86, Histogram Score: 0.9976
# ROI noisy valid ROI - Combined Score: 33.3993, Template Score: -0.0012, Feature Matches: 83, Histogram Score: 0.9991
# ROI clean invalid ROI - Combined Score: 27.4051, Template Score: 0.0172, Feature Matches: 68, Histogram Score: 0.9910
# ROI noisy invalid ROI - Combined Score: 28.9988, Template Score: -0.0011, Feature Matches: 72, Histogram Score: 0.9963
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_18_16_26.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 31.54%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 44.2001, Template Score: 0.0072, Feature Matches: 110, Histogram Score: 0.9859
# ROI noisy valid ROI - Combined Score: 42.2009, Template Score: 0.0076, Feature Matches: 105, Histogram Score: 0.9892
# ROI clean invalid ROI - Combined Score: 24.2008, Template Score: 0.0140, Feature Matches: 60, Histogram Score: 0.9762
# ROI noisy invalid ROI - Combined Score: 22.2045, Template Score: 0.0193, Feature Matches: 55, Histogram Score: 0.9837
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_15_40_21.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.77%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 36.2011, Template Score: 0.0036, Feature Matches: 90, Histogram Score: 0.9982
# ROI noisy valid ROI - Combined Score: 39.0105, Template Score: 0.0265, Feature Matches: 97, Histogram Score: 0.9995
# ROI clean invalid ROI - Combined Score: 26.2004, Template Score: 0.0049, Feature Matches: 65, Histogram Score: 0.9921
# ROI noisy invalid ROI - Combined Score: 23.3991, Template Score: -0.0007, Feature Matches: 58, Histogram Score: 0.9971
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_17_00_21.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 32.85%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 38.6014, Template Score: 0.0080, Feature Matches: 96, Histogram Score: 0.9908
# ROI noisy valid ROI - Combined Score: 42.2039, Template Score: 0.0130, Feature Matches: 105, Histogram Score: 0.9937
# ROI clean invalid ROI - Combined Score: 25.3994, Template Score: 0.0076, Feature Matches: 63, Histogram Score: 0.9819
# ROI noisy invalid ROI - Combined Score: 32.2016, Template Score: 0.0096, Feature Matches: 80, Histogram Score: 0.9889
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_24_18.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 20.58%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 38.2017, Template Score: 0.0067, Feature Matches: 95, Histogram Score: 0.9951
# ROI noisy valid ROI - Combined Score: 36.2023, Template Score: 0.0071, Feature Matches: 90, Histogram Score: 0.9973
# ROI clean invalid ROI - Combined Score: 25.7978, Template Score: 0.0009, Feature Matches: 64, Histogram Score: 0.9874
# ROI noisy invalid ROI - Combined Score: 27.4020, Template Score: 0.0082, Feature Matches: 68, Histogram Score: 0.9935
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_14_16_22.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 23.65%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 30.9983, Template Score: -0.0026, Feature Matches: 77, Histogram Score: 0.9969
# ROI noisy valid ROI - Combined Score: 37.8029, Template Score: 0.0079, Feature Matches: 94, Histogram Score: 0.9986
# ROI clean invalid ROI - Combined Score: 23.4026, Template Score: 0.0115, Feature Matches: 58, Histogram Score: 0.9900
# ROI noisy invalid ROI - Combined Score: 23.3972, Template Score: -0.0047, Feature Matches: 58, Histogram Score: 0.9955
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_18_15_44.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.68%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 32.5999, Template Score: 0.0024, Feature Matches: 81, Histogram Score: 0.9947
# ROI noisy valid ROI - Combined Score: 38.9993, Template Score: -0.0002, Feature Matches: 97, Histogram Score: 0.9969
# ROI clean invalid ROI - Combined Score: 28.6011, Template Score: 0.0095, Feature Matches: 71, Histogram Score: 0.9868
# ROI noisy invalid ROI - Combined Score: 31.0047, Template Score: 0.0152, Feature Matches: 77, Histogram Score: 0.9930
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_27_10_34_54.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 15.93%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 36.2063, Template Score: 0.0158, Feature Matches: 90, Histogram Score: 0.9998
# ROI noisy valid ROI - Combined Score: 31.8031, Template Score: 0.0079, Feature Matches: 79, Histogram Score: 0.9999
# ROI clean invalid ROI - Combined Score: 27.4035, Template Score: 0.0108, Feature Matches: 68, Histogram Score: 0.9958
# ROI noisy invalid ROI - Combined Score: 25.3974, Template Score: -0.0062, Feature Matches: 63, Histogram Score: 0.9993
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_27_11_56_53.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 21.36%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 33.4007, Template Score: 0.0037, Feature Matches: 83, Histogram Score: 0.9962
# ROI noisy valid ROI - Combined Score: 37.4028, Template Score: 0.0078, Feature Matches: 93, Histogram Score: 0.9982
# ROI clean invalid ROI - Combined Score: 25.7973, Template Score: -0.0012, Feature Matches: 64, Histogram Score: 0.9890
# ROI noisy invalid ROI - Combined Score: 24.1983, Template Score: -0.0016, Feature Matches: 60, Histogram Score: 0.9948
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_14_15_27.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 33.69%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 42.5981, Template Score: 0.0021, Feature Matches: 106, Histogram Score: 0.9862
# ROI noisy valid ROI - Combined Score: 45.0018, Template Score: 0.0098, Feature Matches: 112, Histogram Score: 0.9895
# ROI clean invalid ROI - Combined Score: 25.7981, Template Score: 0.0070, Feature Matches: 64, Histogram Score: 0.9765
# ROI noisy invalid ROI - Combined Score: 28.6049, Template Score: 0.0203, Feature Matches: 71, Histogram Score: 0.9840
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_36_49.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 19.27%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 31.0017, Template Score: 0.0044, Feature Matches: 77, Histogram Score: 0.9996
# ROI noisy valid ROI - Combined Score: 31.4008, Template Score: 0.0019, Feature Matches: 78, Histogram Score: 1.0000
# ROI clean invalid ROI - Combined Score: 23.0040, Template Score: 0.0126, Feature Matches: 57, Histogram Score: 0.9949
# ROI noisy invalid ROI - Combined Score: 29.4016, Template Score: 0.0047, Feature Matches: 73, Histogram Score: 0.9989
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_15_08_03.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 18.97%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 35.7962, Template Score: -0.0078, Feature Matches: 89, Histogram Score: 0.9965
# ROI noisy valid ROI - Combined Score: 34.6031, Template Score: 0.0086, Feature Matches: 86, Histogram Score: 0.9983
# ROI clean invalid ROI - Combined Score: 26.6067, Template Score: 0.0222, Feature Matches: 66, Histogram Score: 0.9893
# ROI noisy invalid ROI - Combined Score: 27.3965, Template Score: -0.0062, Feature Matches: 68, Histogram Score: 0.9950
# Kicker is in valid orientation (matched with clean valid ROI).
# cam2024_09_26_17_03_11.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 20.27%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 38.2009, Template Score: 0.0046, Feature Matches: 95, Histogram Score: 0.9954
# ROI noisy valid ROI - Combined Score: 40.2048, Template Score: 0.0132, Feature Matches: 100, Histogram Score: 0.9975
# ROI clean invalid ROI - Combined Score: 24.5967, Template Score: -0.0022, Feature Matches: 61, Histogram Score: 0.9878
# ROI noisy invalid ROI - Combined Score: 24.6009, Template Score: 0.0053, Feature Matches: 61, Histogram Score: 0.9939
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_14_17_39.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 successful. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 16.98%
# Kicker Detected by White Pixels
# Kicker detected (both tests passed).
# ROI clean valid ROI - Combined Score: 35.8070, Template Score: 0.0181, Feature Matches: 89, Histogram Score: 0.9986
# ROI noisy valid ROI - Combined Score: 38.6111, Template Score: 0.0280, Feature Matches: 96, Histogram Score: 0.9997
# ROI clean invalid ROI - Combined Score: 24.2002, Template Score: 0.0042, Feature Matches: 60, Histogram Score: 0.9928
# ROI noisy invalid ROI - Combined Score: 25.3996, Template Score: 0.0003, Feature Matches: 63, Histogram Score: 0.9975
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_27_12_01_29.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 22.53%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 32.5993, Template Score: -0.0008, Feature Matches: 81, Histogram Score: 0.9981
# ROI noisy valid ROI - Combined Score: 33.8005, Template Score: 0.0014, Feature Matches: 84, Histogram Score: 0.9994
# ROI clean invalid ROI - Combined Score: 21.3967, Template Score: -0.0043, Feature Matches: 53, Histogram Score: 0.9919
# ROI noisy invalid ROI - Combined Score: 26.9983, Template Score: -0.0026, Feature Matches: 67, Histogram Score: 0.9970
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_17_06_07.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------
#
#
# Test 1 failed. Checking white pixel coverage...
# White Pixel Percentage in Upper Region: 18.72%
# Kicker Detected by White Pixels
# Kicker detected (based on white pixel coverage).
# ROI clean valid ROI - Combined Score: 32.9991, Template Score: -0.0017, Feature Matches: 82, Histogram Score: 0.9989
# ROI noisy valid ROI - Combined Score: 33.0019, Template Score: 0.0047, Feature Matches: 82, Histogram Score: 0.9998
# ROI clean invalid ROI - Combined Score: 24.2101, Template Score: 0.0285, Feature Matches: 60, Histogram Score: 0.9935
# ROI noisy invalid ROI - Combined Score: 29.7951, Template Score: -0.0112, Feature Matches: 74, Histogram Score: 0.9980
# Kicker is in valid orientation (matched with noisy valid ROI).
# cam2024_09_26_17_04_12.jpg is valid (kicker in correct orientation).
# ----------------------------------------------------------------------

# %%
# import os
# import shutil

# def process_folder(folder_path, reference_roi_valid_path, reference_roi_invalid_path, output_folder):
#     # Create the output folder if it doesn't exist
#     if not os.path.exists(output_folder):
#         os.makedirs(output_folder)

#     # Iterate through all the images in the folder
#     for image_filename in os.listdir(folder_path):
#         image_path = os.path.join(folder_path, image_filename)

#         # Check if the file is an image (based on its extension)
#         if image_filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
#             #print(f"Processing {image_filename}...")

#             # Run the pipeline on the image to check orientation
#             valid_orientation = kicker_pipeline(image_path, reference_roi_valid_path, reference_roi_invalid_path)

#             # If kicker is in an invalid orientation, move the image to the output folder
#             if not valid_orientation:
#                 print(f"Moving {image_filename} to '{output_folder}' (invalid kicker detected).")
#                 shutil.copy(image_path, os.path.join(output_folder, image_filename))
#             else:
#                 print(f"{image_filename} is valid (kicker in correct orientation).")

# # Example usage
# folder_path = 'OneDrive_2024-10-01/Images for Testing/Class 1 - Kicker at front position'
# reference_roi_valid_path = 'Reference_Imgs/reference_roi_valid.jpg'
# reference_roi_invalid_path = 'Reference_Imgs/reference_roi_invalid.jpg'
# output_folder = 'False_images'

# process_folder(folder_path, reference_roi_valid_path, reference_roi_invalid_path, output_folder)
